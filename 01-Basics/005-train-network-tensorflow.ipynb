# %%
import numpy as np
from random import random
from sklearn.model_selection import train_test_split
import tensorflow as tf
# Out:
# 2024-03-26 17:26:52.074940: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
def build_dataset(num_samples, test_size):
    x = np.array([[random() / 2 for _ in range(2)] for _ in range(num_samples)])
    y = np.array([[i[0] + i[1]] for i in x])
    x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=test_size)
    return x_train, x_test, y_train, y_test

# %%
if __name__ == "__main__":
    x_train, x_test, y_train, y_test = build_dataset(5000, 0.3)
    
    # Build the model
    model = tf.keras.Sequential([
        tf.keras.layers.Dense(5, input_dim=2, activation="sigmoid"),
        tf.keras.layers.Dense(1, activation="sigmoid")
    ])
    
    # Compile the model
    optimizer = tf.keras.optimizers.SGD(learning_rate=0.1)
    model.compile(optimizer=optimizer, loss="MSE")
    
    # Train the model
    model.fit(x_train, y_train, epochs=100)
    
    # Evaluate the model
    model.evaluate(x_test, y_test, verbose=1)
    
    # Predict using the model
    data = np.array([[0.1, 0.2], [0.3, 0.4]])
    predictions = model.predict(data)
    
    print("Predictions output")
    for d, p in zip(data, predictions):
        print("{} + {} = {}".format(d[0], d[1], p))
# Out:
# Epoch 1/100
# 110/110 [==============================] - 0s 729us/step - loss: 0.0789
# Epoch 2/100
# 110/110 [==============================] - 0s 703us/step - loss: 0.0442
# Epoch 3/100
# 110/110 [==============================] - 0s 695us/step - loss: 0.0436
# Epoch 4/100
# 110/110 [==============================] - 0s 695us/step - loss: 0.0431
# Epoch 5/100
# 110/110 [==============================] - 0s 683us/step - loss: 0.0426
# Epoch 6/100
# 110/110 [==============================] - 0s 685us/step - loss: 0.0421
# Epoch 7/100
# 110/110 [==============================] - 0s 752us/step - loss: 0.0416
# Epoch 8/100
# 110/110 [==============================] - 0s 712us/step - loss: 0.0412
# Epoch 9/100
# 110/110 [==============================] - 0s 688us/step - loss: 0.0407
# Epoch 10/100
# 110/110 [==============================] - 0s 680us/step - loss: 0.0402
# Epoch 11/100
# 110/110 [==============================] - 0s 709us/step - loss: 0.0397
# Epoch 12/100
# 110/110 [==============================] - 0s 692us/step - loss: 0.0392
# Epoch 13/100
# 110/110 [==============================] - 0s 695us/step - loss: 0.0386
# Epoch 14/100
# 110/110 [==============================] - 0s 735us/step - loss: 0.0381
# Epoch 15/100
# 110/110 [==============================] - 0s 724us/step - loss: 0.0375
# Epoch 16/100
# 110/110 [==============================] - 0s 732us/step - loss: 0.0370
# Epoch 17/100
# 110/110 [==============================] - 0s 847us/step - loss: 0.0364
# Epoch 18/100
# 110/110 [==============================] - 0s 732us/step - loss: 0.0358
# Epoch 19/100
# 110/110 [==============================] - 0s 756us/step - loss: 0.0352
# Epoch 20/100
# 110/110 [==============================] - 0s 752us/step - loss: 0.0345
# Epoch 21/100
# 110/110 [==============================] - 0s 747us/step - loss: 0.0339
# Epoch 22/100
# 110/110 [==============================] - 0s 731us/step - loss: 0.0332
# Epoch 23/100
# 110/110 [==============================] - 0s 746us/step - loss: 0.0325
# Epoch 24/100
# 110/110 [==============================] - 0s 752us/step - loss: 0.0318
# Epoch 25/100
# 110/110 [==============================] - 0s 780us/step - loss: 0.0311
# Epoch 26/100
